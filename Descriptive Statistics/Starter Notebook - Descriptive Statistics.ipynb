# %% [markdown]
# # Wine Dataset
# <img src="https://storage.googleapis.com/kaggle-datasets-images/1436/2571/16febb8d281d37d8d3c73ed7c32679bc/dataset-original.jpg" width=250>

# %% [markdown]
# The code below loads in the data set <b>wine-data.csv</b> into a variable <b>wines</b> as <b>list of lists</b>. <br>We’ll perform statistics on wines.

# %%
import pandas as pd
df = pd.read_csv('wine-data.csv')
df.head(1)
# Out:
#   country                                        description    designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  VulkÃ  Bianco
#
#    points  price           province region_1 region_2      taster_name  \
# 0      87     12  Sicily & Sardinia     Etna      NaN  Kerin Oâ€™Keefe
#
#   taster_twitter_handle                               title      variety  \
# 0          @kerinokeefe  Nicosia 2013 VulkÃ  Bianco  (Etna)  White Blend
#
#     winery
# 0  Nicosia

# %% [markdown]
# ## Measures of Central Tendency

# %% [markdown]
# ### The mean is a descriptive statistic that looks at the average value of a data set.
# <img src="https://i.ibb.co/JFT50Km/Mean.png" alt="Mean" width="450">

# %%
df.mean()
# Out:
# points    88.909091
# price     21.090909
# dtype: float64

# %% [markdown]
# ### Median
# The median also attempts to define a typical value in the data set, but unlike mean, does not require calculation. To find the median, we first need to reorganize our data set in ascending order. Then the median is the value that coincides with the middle of the data set. If there are an even amount of items, then we take the average of the two values that would “surround” the middle.

# %% [markdown]
# <img src="https://i.ibb.co/Zd0LvTB/Median.png" alt="Median" width=400>

# %%
df.median().points
#or df['points'].median()
# Out:
# 87.0

# %% [markdown]
# ### First and Second Quartiles - Inter Quartile Range (IQR)
# <img src="https://i.ibb.co/WBhw0vr/IQR.png" alt="IQR" width=350>

# %%
df.describe()
# Out:
#            points      price
# count   11.000000  11.000000
# mean    88.909091  21.090909
# std      7.435786  15.352228
# min     77.000000  12.000000
# 25%     85.000000  13.500000
# 50%     87.000000  15.000000
# 75%     95.500000  21.500000
# max    100.000000  65.000000

# %% [markdown]
# ### Mode
# The last measure of central tendency that we’ll discuss is the mode. The mode is defined as the value that appears the most frequently in our data. The intuition of the mode as the “middle” is not as immediate as mean or median, but there is a clear rationale. If a value appears repeatedly throughout the data, we also know it will influence the average towards the modal value. The more a value appears, the more it will influence the mean. Thus, a mode represents the highest weighted contributing factor to our mean.

# %%
print(df['price'].mode())
print(df['points'].mode())
# Out:
# 0    12
# 1    15
# dtype: int64
# 0    85
# 1    87
# dtype: int64

# %% [markdown]
# ### Range

# %%
max(df['points']) - min(df['points'])
# Out:
# 23

# %% [markdown]
# ### Variance
# Statistical variance gives a measure of how the data distributes itself about the mean or expected value. Unlike range that only looks at the extremes, the variance looks at all the data points and then determines their distribution.
# <img src="https://i.ibb.co/Lz8Z45J/variance.jpg" alt="variance" width="350">

# %%
df.var()
# Out:
# points     55.290909
# price     235.690909
# dtype: float64

# %% [markdown]
# ### Standard Deviation
# The standard deviation is also a measure of the spread of your observations, but is a statement of how much your data deviates from a typical data point. That is to say, the standard deviation summarizes how much your data differs from the mean.
# <img src="SD.png" width=500>

# %%
df.std()
# Out:
# points     7.435786
# price     15.352228
# dtype: float64

# %% [markdown]
# ### Histogram

# %%
df.hist();

# %% [markdown]
# ### Skew

# %%
df.skew()
# Out:
# points    0.049885
# price     2.766640
# dtype: float64

# %% [markdown]
# ### Q. Which variety of wine has the highest price?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.bar(df['variety'],df['price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Q. Does wine which has got more rating, cost higher?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(df['points'],df['price'],'g^')
plt.show()

# %% [markdown]
# ### Q. Which country has the highest quality (rating) wine, on an average?

# %%
import numpy as np
wine = df['points'].groupby(df['country'])
wine_mean = wine.agg(np.mean)
wine_mean
# Out:
# country
# France      91.50
# Germany     85.00
# Italy       82.00
# Portugal    95.00
# Spain       98.00
# US          88.25
# Name: points, dtype: float64

# %%
import pandas as pd
df = pd.read_csv('matches.csv')
df.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
mat = df.groupby(df['city'],as_index=False)
new = mat.count()
new
# Out:
#               city  id  season  date  team1  team2  toss_winner  \
# 0        Abu Dhabi   7       7     7      7      7            7
# 1        Ahmedabad  12      12    12     12     12           12
# 2        Bangalore  66      66    66     66     66           66
# 3     Bloemfontein   2       2     2      2      2            2
# 4        Cape Town   7       7     7      7      7            7
# 5        Centurion  12      12    12     12     12           12
# 6       Chandigarh  46      46    46     46     46           46
# 7          Chennai  48      48    48     48     48           48
# 8          Cuttack   7       7     7      7      7            7
# 9            Delhi  60      60    60     60     60           60
# 10      Dharamsala   9       9     9      9      9            9
# 11          Durban  15      15    15     15     15           15
# 12     East London   3       3     3      3      3            3
# 13       Hyderabad  49      49    49     49     49           49
# 14          Indore   5       5     5      5      5            5
# 15          Jaipur  33      33    33     33     33           33
# 16    Johannesburg   8       8     8      8      8            8
# 17          Kanpur   4       4     4      4      4            4
# 18       Kimberley   3       3     3      3      3            3
# 19           Kochi   5       5     5      5      5            5
# 20         Kolkata  61      61    61     61     61           61
# 21          Mumbai  85      85    85     85     85           85
# 22          Nagpur   3       3     3      3      3            3
# 23  Port Elizabeth   7       7     7      7      7            7
# 24            Pune  32      32    32     32     32           32
# 25          Raipur   6       6     6      6      6            6
# 26          Rajkot  10      10    10     10     10           10
# 27          Ranchi   7       7     7      7      7            7
# 28         Sharjah   6       6     6      6      6            6
# 29   Visakhapatnam  11      11    11     11     11           11
#
#     toss_decision  result  dl_applied  winner  win_by_runs  win_by_wickets  \
# 0               7       7           7       7            7               7
# 1              12      12          12      12           12              12
# 2              66      66          66      64           66              66
# 3               2       2           2       2            2               2
# 4               7       7           7       7            7               7
# 5              12      12          12      12           12              12
# 6              46      46          46      46           46              46
# 7              48      48          48      48           48              48
# 8               7       7           7       7            7               7
# 9              60      60          60      59           60              60
# 10              9       9           9       9            9               9
# 11             15      15          15      15           15              15
# 12              3       3           3       3            3               3
# 13             49      49          49      49           49              49
# 14              5       5           5       5            5               5
# 15             33      33          33      33           33              33
# 16              8       8           8       8            8               8
# 17              4       4           4       4            4               4
# 18              3       3           3       3            3               3
# 19              5       5           5       5            5               5
# 20             61      61          61      61           61              61
# 21             85      85          85      85           85              85
# 22              3       3           3       3            3               3
# 23              7       7           7       7            7               7
# 24             32      32          32      32           32              32
# 25              6       6           6       6            6               6
# 26             10      10          10      10           10              10
# 27              7       7           7       7            7               7
# 28              6       6           6       6            6               6
# 29             11      11          11      11           11              11
#
#     player_of_match  venue  umpire1  umpire2  umpire3
# 0                 7      7        7        7        0
# 1                12     12       12       12        0
# 2                64     66       65       65        0
# 3                 2      2        2        2        0
# 4                 7      7        7        7        0
# 5                12     12       12       12        0
# 6                46     46       46       46        0
# 7                48     48       48       48        0
# 8                 7      7        7        7        0
# 9                59     60       60       60        0
# 10                9      9        9        9        0
# 11               15     15       15       15        0
# 12                3      3        3        3        0
# 13               49     49       49       49        0
# 14                5      5        5        5        0
# 15               33     33       33       33        0
# 16                8      8        8        8        0
# 17                4      4        4        4        0
# 18                3      3        3        3        0
# 19                5      5        5        5        0
# 20               61     61       61       61        0
# 21               85     85       85       85        0
# 22                3      3        3        3        0
# 23                7      7        7        7        0
# 24               32     32       32       32        0
# 25                6      6        6        6        0
# 26               10     10       10       10        0
# 27                7      7        7        7        0
# 28                6      6        6        6        0
# 29               11     11       11       11        0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.bar(new['city'],new['id'])
plt.xticks(rotation=90)
plt.show()

# %%
mat = df.groupby(df['winner'],as_index=False)
new = mat.count()
new
import matplotlib.pyplot as plt
# %matplotlib inline
plt.bar(new['winner'],new['id'])
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('deliveries.csv')
df.head(1000)
# Out:
#      match_id  inning                 batting_team  \
# 0           1       1          Sunrisers Hyderabad
# 1           1       1          Sunrisers Hyderabad
# 2           1       1          Sunrisers Hyderabad
# 3           1       1          Sunrisers Hyderabad
# 4           1       1          Sunrisers Hyderabad
# ..        ...     ...                          ...
# 995         5       1  Royal Challengers Bangalore
# 996         5       1  Royal Challengers Bangalore
# 997         5       1  Royal Challengers Bangalore
# 998         5       1  Royal Challengers Bangalore
# 999         5       1  Royal Challengers Bangalore
#
#                     bowling_team  over  ball        batsman non_striker  \
# 0    Royal Challengers Bangalore     1     1      DA Warner    S Dhawan
# 1    Royal Challengers Bangalore     1     2      DA Warner    S Dhawan
# 2    Royal Challengers Bangalore     1     3      DA Warner    S Dhawan
# 3    Royal Challengers Bangalore     1     4      DA Warner    S Dhawan
# 4    Royal Challengers Bangalore     1     5      DA Warner    S Dhawan
# ..                           ...   ...   ...            ...         ...
# 995             Delhi Daredevils     6     4  Mandeep Singh   SR Watson
# 996             Delhi Daredevils     6     5  Mandeep Singh   SR Watson
# 997             Delhi Daredevils     6     6      KM Jadhav   SR Watson
# 998             Delhi Daredevils     7     1      SR Watson   KM Jadhav
# 999             Delhi Daredevils     7     2      KM Jadhav   SR Watson
#
#          bowler  is_super_over  ...  bye_runs  legbye_runs  noball_runs  \
# 0      TS Mills              0  ...         0            0            0
# 1      TS Mills              0  ...         0            0            0
# 2      TS Mills              0  ...         0            0            0
# 3      TS Mills              0  ...         0            0            0
# 4      TS Mills              0  ...         0            0            0
# ..          ...            ...  ...       ...          ...          ...
# 995  PJ Cummins              0  ...         0            0            0
# 996  PJ Cummins              0  ...         0            0            0
# 997  PJ Cummins              0  ...         0            0            0
# 998    S Nadeem              0  ...         0            0            0
# 999    S Nadeem              0  ...         0            0            0
#
#      penalty_runs  batsman_runs  extra_runs  total_runs  player_dismissed  \
# 0               0             0           0           0               NaN
# 1               0             0           0           0               NaN
# 2               0             4           0           4               NaN
# 3               0             0           0           0               NaN
# 4               0             0           2           2               NaN
# ..            ...           ...         ...         ...               ...
# 995             0             0           0           0               NaN
# 996             0             0           0           0     Mandeep Singh
# 997             0             0           0           0               NaN
# 998             0             1           0           1               NaN
# 999             0             1           0           1               NaN
#
#     dismissal_kind fielder
# 0              NaN     NaN
# 1              NaN     NaN
# 2              NaN     NaN
# 3              NaN     NaN
# 4              NaN     NaN
# ..             ...     ...
# 995            NaN     NaN
# 996         bowled     NaN
# 997            NaN     NaN
# 998            NaN     NaN
# 999            NaN     NaN
#
# [1000 rows x 21 columns]

# %%
mat = df.groupby(df['batsman'],as_index=False)
new2=mat.sum()
new3 = new2.sort_values(by='batsman_runs',ascending=False)
new = new3.head(10)

import matplotlib.pyplot as plt
# %matplotlib inline


plt.bar(new['batsman'],new['batsman_runs'],width=0.5)
plt.xticks(rotation=90)
plt.show()

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('matches.csv')

#mat = df.groupby(df['winner'],as_index=False)
a = df[df['winner'] == df['toss_winner']]
x = a.count()

b = df[df['winner'] != df['toss_winner']]
y = b.count()

print(x['id'])

import matplotlib.pyplot as plt
# %matplotlib inline

index = np.arange(1)
bar_width= 0.1
fig, ax = plt.subplots()

ax.bar(index,x['id'],bar_width,label="toss winner")
ax.bar(index+bar_width,y['id'],bar_width,label="toss loser")

plt.show()
# Out:
# 325
